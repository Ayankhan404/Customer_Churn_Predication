# %%
#import Libraries
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#Load Data
df = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
#check data types
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %% [markdown]
# ## here is TotalCharges is object but it is floating value now we can change the object data type to float

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# We can check the null value using heat map
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
#parcentage of null values
df.isna().mean()*100
# Out:
# customerID          0.0
# gender              0.0
# SeniorCitizen       0.0
# Partner             0.0
# Dependents          0.0
# tenure              0.0
# PhoneService        0.0
# MultipleLines       0.0
# InternetService     0.0
# OnlineSecurity      0.0
# OnlineBackup        0.0
# DeviceProtection    0.0
# TechSupport         0.0
# StreamingTV         0.0
# StreamingMovies     0.0
# Contract            0.0
# PaperlessBilling    0.0
# PaymentMethod       0.0
# MonthlyCharges      0.0
# TotalCharges        0.0
# Churn               0.0
# dtype: float64

# %%
# df['TotalCharges']=df['TotalCharges'].astype(float)
# df=df.astype({'TotalCharges':'float'})

# df['TotalCharges']=pd.to_numeric(df['TotalCharges'],errors='coerce')
# df['TotalCharges'].dtype

# %%
#check Total Changes have null values od not 
df[df['TotalCharges']==" "]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %%
## handling missing value
# df['TotalCharges']=df['TotalCharges'].fillna(0.0)

#or 
df['TotalCharges']=df['TotalCharges'].replace({" ":0.0})

# %%
df['TotalCharges']=df['TotalCharges'].astype(float)
# df=df.astype({'TotalCharges':'float'})

# df['TotalCharges']=pd.to_numeric(df['TotalCharges'],errors='coerce')
df['TotalCharges'].dtype
# Out:
# dtype('float64')

# %%
## We don't need customer id then we can drop it
df = df.drop(columns=['customerID'])

# %%
df.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
numeric_features=df.select_dtypes(include=["float","int"]).columns
numeric_features
# df.select_dtypes(include=["number"]).columns
# df.select_dtypes(float,int).columns
# df._get_numeric_data()
# Out:
# Index(['SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges'], dtype='object')

# %%
# printing the unique values
for col in df.columns:
   if col not in numeric_features:
    print(col,df[col].unique())
    print("  ")
    print('*'*50)
# Out:
# gender ['Female' 'Male']
#
# **************************************************
# Partner ['Yes' 'No']
#
# **************************************************
# Dependents ['No' 'Yes']
#
# **************************************************
# PhoneService ['No' 'Yes']
#
# **************************************************
# MultipleLines ['No phone service' 'No' 'Yes']
#
# **************************************************
# InternetService ['DSL' 'Fiber optic' 'No']
#
# **************************************************
# OnlineSecurity ['No' 'Yes' 'No internet service']
#
# **************************************************
# OnlineBackup ['Yes' 'No' 'No internet service']
#
# **************************************************
# DeviceProtection ['No' 'Yes' 'No internet service']
#
# **************************************************
# TechSupport ['No' 'Yes' 'No internet service']
#
# **************************************************
# ...

# %%
## print all unquie numerical columns values 
for col in df.columns:
   if col in numeric_features:
    print(col,df[col].unique())
    print("  ")
    print('*'*50)
# Out:
# SeniorCitizen [0 1]
#
# **************************************************
# tenure [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26  0
#  39]
#
# **************************************************
# MonthlyCharges [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
#
# **************************************************
# TotalCharges [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
#
# **************************************************

# %%
df['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %% [markdown]
# **Insights:**
# 1. Customer ID removed as it is not required for modelling
# 2. No mmissing values in the dataset
# 3. Missing values in the TotalCharges column were replaced with 0
# 4. Class imbalance identified in the target

# %%
#EDA
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        0.162147    32.371149       64.761692   2279.734304
# std         0.368612    24.559481       30.090047   2266.794470
# min         0.000000     0.000000       18.250000      0.000000
# 25%         0.000000     9.000000       35.500000    398.550000
# 50%         0.000000    29.000000       70.350000   1394.550000
# 75%         0.000000    55.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000

# %% [markdown]
# ### numerical Feature Analysis

# %%
numeric_features
# Out:
# Index(['SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges'], dtype='object')

# %%
plt.figure(figsize=(15, 10))
plt.suptitle("Univariate Analysis of Numerical Columns", fontsize=20, fontweight='bold', alpha=0.8, y=1.02)

for i in range(len(numeric_features)):
    plt.subplot(2, 2, i + 1)  # Ensure grid is sufficient for number of plots
    sns.kdeplot(x=df[numeric_features[i]], color='blue')
    plt.xlabel(numeric_features[i])  # Corrected method name
    plt.tight_layout()

plt.show()

# %%
categorial_fearues=df.select_dtypes(include=["object"]).columns
categorial_fearues
# Out:
# Index(['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'Churn'],
#       dtype='object')

# %%
plt.figure(figsize=(8,4))
sns.histplot(data=df,x='tenure',kde=True)
plt.title("tenure Distribution")
plt.ylabel('Frequence')
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.histplot(data=df,x='MonthlyCharges',kde=True)
plt.title("MonthlyCharges Distribution")
plt.ylabel('Frequence')
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.histplot(data=df,x='TotalCharges',kde=True)
plt.title("TotalCharges Distribution")
plt.ylabel('Frequence')
plt.show()

# %%
def plot_boxplot(df,column_name):
    
    plt.figure(figsize=(5,3))
    sns.boxplot(y=df[column_name])
    plt.title(f"Box plot of {column_name}")
    plt.ylabel(column_name)
    plt.show()

# %%
plot_boxplot(df,"tenure")

# %%
plot_boxplot(df,"MonthlyCharges")

# %%
plot_boxplot(df,"TotalCharges")

# %%
corr=df.drop(columns='SeniorCitizen').corr()

# %%
corr
# Out:
#                   tenure  MonthlyCharges  TotalCharges
# tenure          1.000000        0.247900      0.826178
# MonthlyCharges  0.247900        1.000000      0.651174
# TotalCharges    0.826178        0.651174      1.000000

# %%
#correlation matrix - heatmap
plt.figure(figsize=(8,5))
sns.heatmap(data=corr,annot=True)
plt.title("Correlation Heatmap")
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
categorial_fearues=df.select_dtypes(include=["object"]).columns.to_list()
categorial_fearues
# Out:
# ['gender',
#  'Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'Churn']

# %%
categorial_fearues = categorial_fearues + ['SeniorCitizen']
categorial_fearues
# Out:
# ['gender',
#  'Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'Churn',
#  'SeniorCitizen']

# %%
## conut plot for categorical columns

for col in categorial_fearues:
    plt.figure(figsize=(10,3))
    sns.countplot(x=df[col])
    plt.title(f'Count of {col}', fontsize=14, fontweight='bold')

# %% [markdown]
# #### Data preprocessing

# %%
# Label encoding of targget column
df['Churn']=df['Churn'].replace({'Yes':1,'No':0})

# %%
#Label encoding on categorical column
categorial_fearues=df.select_dtypes('object').columns
categorial_fearues
# Out:
# Index(['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
import pickle

# %%
encoder={}

#apply lable encoder and store the encoders
for col in categorial_fearues:
    le=LabelEncoder()
    df[col]=le.fit_transform(df[col])
    encoder[col]=le

#save the encoder to pickle file 
with open("encoder.pkl","wb") as f:
    pickle.dump(encoder,f)

# %%
encoder
# Out:
# {'gender': LabelEncoder(),
#  'Partner': LabelEncoder(),
#  'Dependents': LabelEncoder(),
#  'PhoneService': LabelEncoder(),
#  'MultipleLines': LabelEncoder(),
#  'InternetService': LabelEncoder(),
#  'OnlineSecurity': LabelEncoder(),
#  'OnlineBackup': LabelEncoder(),
#  'DeviceProtection': LabelEncoder(),
#  'TechSupport': LabelEncoder(),
#  'StreamingTV': LabelEncoder(),
#  'StreamingMovies': LabelEncoder(),
#  'Contract': LabelEncoder(),
#  'PaperlessBilling': LabelEncoder(),
#  'PaymentMethod': LabelEncoder()}

# %%
df.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              1                0               0             2
# 1              0                0               2             0
# 2              0                0               2             2
# 3              1                0               2             0
# 4              0                1               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
x=df.drop(columns=['Churn'])
y=df['Churn']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (5634, 19)

# %%
x_test.shape
# Out:
# (1409, 19)

# %%
## handling Imbalaced data
from imblearn.over_sampling import SMOTE

oversample=SMOTE(random_state=42)
x_train_smote,y_train_smote = oversample.fit_resample(x_train,y_train)

# %%
print(y_train_smote.shape)
print(x_train_smote.shape)
# Out:
# (8276,)
# (8276, 19)

# %%
print(y_train_smote.value_counts())
# Out:
# 0    4138
# 1    4138
# Name: Churn, dtype: int64

# %%
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix ,classification_report

# %%
tr=tree.DecisionTreeClassifier(random_state=42)
rf=RandomForestClassifier(random_state=42)
xb=XGBClassifier(random_state=42)

# %%
tr.fit(x_train_smote,y_train_smote)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred_tr=tr.predict(x_test)
y_pred_tr
# Out:
# array([1, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
report1=classification_report(y_test,y_pred_tr)
print(report1)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.79      0.81      1036
#            1       0.48      0.55      0.51       373
#
#     accuracy                           0.73      1409
#    macro avg       0.66      0.67      0.66      1409
# weighted avg       0.74      0.73      0.73      1409

# %%
tr.score(x_test,y_test)
# Out:
# 0.7260468417317246

# %%
rf.fit(x_train_smote,y_train_smote)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred_rf=rf.predict(x_test)
y_pred_rf
# Out:
# array([1, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
rf.score(x_test,y_test)
# Out:
# 0.7771469127040455

# %%
report2=classification_report(y_test,y_pred_rf)
print(report2)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85      1036
#            1       0.58      0.58      0.58       373
#
#     accuracy                           0.78      1409
#    macro avg       0.71      0.71      0.71      1409
# weighted avg       0.78      0.78      0.78      1409

# %%
xb.fit(x_train_smote,y_train_smote)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
y_pred_xb=xb.predict(x_test)
y_pred_xb
# Out:
# array([1, 0, 0, ..., 0, 0, 1])

# %%
xb.score(x_test,y_test)
# Out:
# 0.7821149751596878

# %%
report3=classification_report(y_test,y_pred_xb)
print(report3)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85      1036
#            1       0.59      0.59      0.59       373
#
#     accuracy                           0.78      1409
#    macro avg       0.72      0.72      0.72      1409
# weighted avg       0.78      0.78      0.78      1409

# %%
print(cross_val_score(XGBClassifier(),x_train_smote,y_train_smote))
print(cross_val_score(tree.DecisionTreeClassifier(),x_train_smote,y_train_smote))
print(cross_val_score(RandomForestClassifier(),x_train_smote,y_train_smote))
# Out:
# [0.71135266 0.74864048 0.91178248 0.88640483 0.91117825]
# [0.68780193 0.71238671 0.82175227 0.83867069 0.84773414]
# [0.73007246 0.76978852 0.90030211 0.89546828 0.89728097]

# %%
cm_rf=confusion_matrix(y_test,y_pred_rf)
cm_tr=confusion_matrix(y_test,y_pred_tr)
cm_xb=confusion_matrix(y_test,y_pred_xb)

# %%
cm_rf
# Out:
# array([[879, 157],
#        [157, 216]], dtype=int64)

# %%
cm_tr
# Out:
# array([[819, 217],
#        [169, 204]], dtype=int64)

# %%
cm_xb
# Out:
# array([[882, 154],
#        [153, 220]], dtype=int64)

# %%
# sns.heatmap(cm_rf,annot=True)

# %%
# # model training 
# #hyperparameter 
# models={
#     "Decision Tree": tree.DecisionTreeClassifier(random_state=42),
#     "Random Forest": RandomForestClassifier(random_state=42),
#     "XGBoost":XGBClassifier(random_state=42)
    
# }

# %%
# # dictionary to store the cross validation score
# cv_score={}

# #perform cross validation
# for model_name,model in models.items():
#     print("Training {model_name} with default parameters")
#     scores=cross_val_score(model,x_train_smote,y_train_smote,cv=5,scoring="accuracy")
#     cv_score[model_name]=scores
#     print(f"{model_name} cross-validation accuracy:{np.mean(scores):2f}")
#     print("*"*50)

# %%
# cv_score

# %%
# save the trained model as a pickle file
model_data = {"model": xb, "features_names": x.columns.tolist()}


with open("customer_churn_model.pkl", "wb") as f:
  pickle.dump(model_data, f)

# %%
# load teh saved model and the feature names

with open("customer_churn_model.pkl", "rb") as f:
  model_data = pickle.load(f)

loaded_model = model_data["model"]
feature_names = model_data["features_names"]

# %%
print(loaded_model)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
print(feature_names)
# Out:
# ['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges', 'TotalCharges']

# %%
input_data = {
    'gender': 'Female',
    'SeniorCitizen': 0,
    'Partner': 'Yes',
    'Dependents': 'No',
    'tenure': 1,
    'PhoneService': 'No',
    'MultipleLines': 'No phone service',
    'InternetService': 'DSL',
    'OnlineSecurity': 'No',
    'OnlineBackup': 'Yes',
    'DeviceProtection': 'No',
    'TechSupport': 'No',
    'StreamingTV': 'No',
    'StreamingMovies': 'No',
    'Contract': 'Month-to-month',
    'PaperlessBilling': 'Yes',
    'PaymentMethod': 'Electronic check',
    'MonthlyCharges': 29.85,
    'TotalCharges': 29.85
}


input_data_df = pd.DataFrame([input_data])

with open("encoder.pkl", "rb") as f:
  encoder = pickle.load(f)


# encode categorical featires using teh saved encoders
for column, encoder in encoder.items():
  input_data_df[column] = encoder.transform(input_data_df[column])

# make a prediction
prediction = loaded_model.predict(input_data_df)
pred_prob = loaded_model.predict_proba(input_data_df)

print(prediction)

# results
print(f"Prediction: {'Churn' if prediction[0] == 1 else 'No Churn'}")
print(f"Prediciton Probability: {pred_prob}")
# Out:
# [0]
# Prediction: No Churn
# Prediciton Probability: [[0.524523 0.475477]]
